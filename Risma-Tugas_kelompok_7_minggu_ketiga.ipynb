# %% [markdown]
# <a href="https://colab.research.google.com/github/rismawsaputri/ADW2026/blob/main/Risma-Tugas_kelompok_7_minggu_ketiga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUGAS KELOMPOK 7

# %% [markdown]
# #Nomor 1
#
# 1. Buatlah simulasi deret MA (1) dengan panjang pengamatan 20 dengan nilai parameter $\theta=0.1, \theta=0.3, \theta=0.7, \theta=1.0, \theta=1.5, \theta=2.0$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

np.random.seed(98)

theta_list = [0.1, 0.3, 0.7, 1.0, 1.5, 2.0]

hasil_ma1 = {}

fig, ax = plt.subplots(2, 3, figsize=(15, 7))
ax = ax.flatten()

for j, theta in enumerate(theta_list):

    et = [np.random.normal(0,1)]
    ma1_m = []

    for i in range(20):
        et.append(np.random.normal(0,1))
        ma1_m.append(et[i+1] - theta*et[i])

    hasil_ma1[theta] = np.array(ma1_m)

    ax[j].plot(ma1_m, '-o')
    ax[j].set_title(f'MA(1), θ = {theta}')
    ax[j].set_xlabel('Waktu')
    ax[j].set_ylabel(r'$Y_t$')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Nomor 2
#
# 2. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 1 dan bandingkan. Berdasarkan plot ACF tersebut, apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA, kaitkan nilai autokorelasi sampel dengan nilai autokorelasi MA(1) secara teori.)

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 7))
ax = ax.flatten()

for j, theta in enumerate(theta_list):

    plot_acf(
        hasil_ma1[theta],
        zero=False,
        ax=ax[j]
    )

    ax[j].set_title(f'ACF MA(1), θ = {theta}')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Nomor 3 dan 4
#
# MA (1) dengan parameter  θ=0.25

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **n = 60**

# %%
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, -0.25])
ma_object1 = ArmaProcess(ar1,ma1)
ma1 = ma_object1.generate_sample(nsample=60)

plt.figure()
plt.plot(ma1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Untuk melihat apakah terdapat hubungan dalam deret antar waktu kita lihat dari plot pencar data berpasangan.

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Plot ACF (*Autocorelation Function*)

# %%
plot_acf(ma1, zero=False)
plt.show()

# %% [markdown]
# **n = 120**

# %%
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, -0.25])
ma_object1 = ArmaProcess(ar1,ma1)
ma1 = ma_object1.generate_sample(nsample=100)

plt.figure()
plt.plot(ma1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Untuk melihat apakah terdapat hubungan dalam deret antar waktu kita lihat dari plot pencar data berpasangan.

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Plot ACF (*Autocorelation Function*)

# %%
plot_acf(ma1, zero=False)
plt.show()

# %% [markdown]
# **n = 150**

# %%
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, -0.25])
ma_object1 = ArmaProcess(ar1,ma1)
ma1 = ma_object1.generate_sample(nsample=150)

plt.figure()
plt.plot(ma1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Untuk melihat apakah terdapat hubungan dalam deret antar waktu kita lihat dari plot pencar data berpasangan.

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Plot ACF (*Autocorelation Function*)

# %%
plot_acf(ma1, zero=False)
plt.show()

# %% [markdown]
# **n = 300**

# %%
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, -0.25])
ma_object1 = ArmaProcess(ar1,ma1)
ma1 = ma_object1.generate_sample(nsample=300)

plt.figure()
plt.plot(ma1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Untuk melihat apakah terdapat hubungan dalam deret antar waktu kita lihat dari plot pencar data berpasangan.

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %% [markdown]
# Plot ACF (*Autocorelation Function*)

# %%
plot_acf(ma1, zero=False)
plt.show()

# %% [markdown]
# # Nomor 5
#
# 5 a. Simulasi MA (2) dengan 50 pengamatan parameter theta 1 = 0,3 dan theta 2 = 0,8

# %%
import numpy as np
from statsmodels.tsa.arima_process import ArmaProcess
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, -0,3, -0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2 = ArmaProcess(ar1,ma1)
ma2 = ma_object2.generate_sample(nsample=50)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(ma2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))

plot_acf(ma2, lags=15, zero=False)

plt.title('ACF MA(2), θ1 = 0.3, θ2 = 0.8')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

plt.show()

# %% [markdown]
# ### 5 B. θ1 = -0.3, θ2 = 0.8

# %%
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, 0,3, -0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2 = ArmaProcess(ar1,ma1)
ma2 = ma_object2.generate_sample(nsample=50)

# %%
plt.figure()
plt.plot(ma2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(ma2, zero=False)
plt.title('ACF MA(2), θ1 = -0.3, θ2 = 0.8')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# 5 C. θ1 = 0.3, θ2 = -0.8

# %%
np.random.seed(98)
ar1 = np.array([1])
ma1 = np.array([1, -0,3, 0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2 = ArmaProcess(ar1,ma1)
ma2 = ma_object2.generate_sample(nsample=120)

# %%
plt.figure()
plt.plot(ma2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(ma2, zero=False)
plt.title('ACF MA(2), θ1 = 0.3, θ2 = -0.8')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

plt.show()

# %% [markdown]
# # 5 D. θ1 = -0.3, θ2 = -0.8

# %%
np.random.seed(1)
theta1, theta2=-0.5, -0.7
ma2_m=[]
et=[np.random.normal(0,1),np.random.normal(0,1)]
for i in range(120):
    et.append(np.random.normal(0,1))
    ma2_m.append(et[i+2]-theta1*et[i+1]-theta2*et[i])

# %%
plt.figure()
plt.plot(ma2_m)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=3, c='k')
plt.xlabel(r'$Y_{t-3}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma2_m), lag=4, c='k')
plt.xlabel(r'$Y_{t-4}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma2_m), zero=False)
plt.title('ACF MA(2), θ1 = -0.3, θ2 = -0.8')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# ## Nomor 6

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf

# Set seed sesuai jumlah 2 digit terakhir NIM anggota
np.random.seed(98)

# Parameter MA(2)
models = {
    'a': (0.3, 0.8),
    'b': (-0.3, 0.8),
    'c': (0.3, -0.8),
    'd': (-0.3, -0.8)
}

# Membuat 4 grafik ACF
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for ax, (label, (theta1, theta2)) in zip(axes.flatten(), models.items()):

    # Model MA(2)
    ar = np.array([1])
    ma = np.array([1, theta1, theta2])

    ma_process = ArmaProcess(ar, ma)

    # Simulasi 50 pengamatan
    data = ma_process.generate_sample(nsample=50)

    # Plot ACF
    plot_acf(data, lags=15, zero=False, ax=ax)

    ax.set_title(
        f'ACF MA(2) - {label}: θ1 = {theta1}, θ2 = {theta2}'
    )
    ax.set_xlabel('Lag')
    ax.set_ylabel('Autocorrelation')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Nomor 7
# 7. Buatlah simulasi deret AR (1) 100 pengamatan dengan nilai parameter $\phi=0.3, \phi=0.9, \phi=-0.3, \phi=-0.9$

# %%
np.random.seed(98)

phis_7 = [0.3, 0.9, -0.3, -0.9]
n7 = 100
ar1_dict = {}

for phi in phis_7:
    ar = np.array([1, -phi])  # koefisien AR dalam sintaks ArmaProcess = -phi (nilai parameter asli)
    ma = np.array([1])
    ar_obj = ArmaProcess(ar, ma)
    ar1_dict[phi] = ar_obj.generate_sample(nsample=n7)

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, phi in zip(axes.flatten(), phis_7):
    ax.plot(ar1_dict[phi])
    ax.set_title(fr'AR(1), $\phi$={phi}')
    ax.set_xlabel('Waktu'); ax.set_ylabel(r'$Y_t$')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Nomor 8
# 8. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 7 dan bandingkan. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(1)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)

# %% [markdown]
# **ACF**

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, phi in zip(axes.flatten(), phis_7):
    plot_acf(ar1_dict[phi], zero=False, ax=ax)
    ax.set_title(fr'ACF AR(1), $\phi$={phi}')
plt.tight_layout()
plt.show()

# %% [markdown]
# **PACF**

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, phi in zip(axes.flatten(), phis_7):
    plot_pacf(ar1_dict[phi], zero=False, ax=ax)
    ax.set_title(fr'PACF AR(1), $\phi$={phi}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Nomor 9
# 9. Berdasarkan plot ACF dan PACF pada nomor 8, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.
# **AR(1)**

# %% [markdown]
# **Nomor 10**

# %% [markdown]
# 1.   ϕ1=1.5,ϕ2=−0.5

# %%
np.random.seed(98)
np.random.seed(98)
psi1, psi2=1.5,-0.5
ar2=[np.random.uniform(0,1),np.random.uniform(0,1)]
for i in range(100):
    ar2.append(psi1*ar2[i+1]+psi2*ar2[i]+np.random.normal(0,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plot_acf(np.array(ar2), zero=False)
plt.show()

# %%
plot_pacf(np.array(ar2), zero=False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess

# Set seed
np.random.seed(98)

# Parameter AR(2)
models_ar2 = {
    'a': (1.5, -0.5),
    'b': (0.75, -0.25),
    'c': (1.0, -0.25),
    'd': (0.5, -0.75)
}

# Menyimpan hasil simulasi
simulasi_ar2 = {}

for label, (phi1, phi2) in models_ar2.items():

    # Dalam statsmodels:
    # AR = [1, -phi1, -phi2]
    ar = np.array([1, -phi1, -phi2])
    ma = np.array([1])

    ar_process = ArmaProcess(ar, ma)

    # Simulasi 100 pengamatan
    data = ar_process.generate_sample(nsample=100)

    simulasi_ar2[label] = data

# Menampilkan hasil simulasi dalam 4 grafik
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for ax, (label, data) in zip(axes.flatten(), simulasi_ar2.items()):

    phi1, phi2 = models_ar2[label]

    ax.plot(data)
    ax.set_title(
        f'AR(2) - {label}: φ1 = {phi1}, φ2 = {phi2}'
    )
    ax.set_xlabel('Waktu')
    ax.set_ylabel(r'$Y_t$')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Nomor 11
# ACF dan PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# Membuat figure ACF
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for ax, (label, data) in zip(axes.flatten(), simulasi_ar2.items()):

    phi1, phi2 = models_ar2[label]

    plot_acf(
        data,
        lags=20,
        zero=False,
        ax=ax
    )

    ax.set_title(
        f'ACF AR(2) - {label}: φ1 = {phi1}, φ2 = {phi2}'
    )
    ax.set_xlabel('Lag')
    ax.set_ylabel('Autocorrelation')

plt.tight_layout()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for ax, (label, data) in zip(axes.flatten(), simulasi_ar2.items()):

    phi1, phi2 = models_ar2[label]

    plot_pacf(data, lags=20, zero=False, ax=ax)

    ax.set_title(
        f'PACF AR(2) - {label}: φ1 = {phi1}, φ2 = {phi2}'
    )
    ax.set_xlabel('Lag')
    ax.set_ylabel('Partial Autocorrelation')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Nomor 12
#
# 12. Berdasarkan plot ACF dan PACF pada nomor 11, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.
#
#
# Berdasarkan plot ACF dan PACF, model yang disarankan adalah:
#
# 1. Deret a (φ₁ = 1.5, φ₂ = -0.5)
# Model yang disarankan: AR(1).
# Hal ini karena PACF menunjukkan spike signifikan pada lag 1 kemudian nilai berikutnya mendekati nol (cut off pada lag 1).
#
# 2. Deret b (φ₁ = 0.75, φ₂ = -0.25)
# Model yang disarankan: AR(2).
# Hal ini karena PACF menunjukkan spike hingga lag 2 kemudian meluruh (cut off pada lag 2).
#
# 3. Deret c (φ₁ = 1.0, φ₂ = -0.25)
# Model yang disarankan: AR(1).
# Hal ini karena pengaruh terbesar terlihat pada lag 1 dan PACF setelahnya cenderung mendekati nol.
#
# 4. Deret d (φ₁ = 0.5, φ₂ = -0.75)
# Model yang disarankan: AR(2).
# Hal ini karena PACF menunjukkan pengaruh sampai lag 2 sebelum mendekati nol.
#
# **Kesimpulan:**
#
# Berdasarkan pola PACF, deret dengan cut off pada lag 1 mengikuti model AR(1), sedangkan deret dengan cut off pada lag 2 mengikuti model AR(2).
